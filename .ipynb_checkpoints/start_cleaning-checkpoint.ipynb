# %%
import pandas as pd
df = pd.read_csv("clean_data2.csv",delimiter='\t',names=['id','datetime','lat','long',"week","ordre"],low_memory=False)
df['datetime'] = pd.to_datetime(df['datetime'])

# %% [markdown]
# # Plot Data

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
def plot(df,week_number):
    large = 22; med = 16; small = 12
    params = {'axes.titlesize': large,
              'legend.fontsize': med,
              'figure.figsize': (16, 10),
              'axes.labelsize': med,
              'axes.titlesize': med,
              'xtick.labelsize': med,
              'ytick.labelsize': med,
              'figure.titlesize': large}
    plt.rcParams.update(params)
    plt.style.use('seaborn-whitegrid')
    sns.set_style("white")
    # %matplotlib inline
    # Create Fig and gridspec
    fig = plt.figure(figsize=(16, 10), dpi= 80)
    grid = plt.GridSpec(4, 4, hspace=0.5, wspace=0.2)

    # Define the axes
    ax_main = fig.add_subplot(grid[:-1, :-1])
    ax_right = fig.add_subplot(grid[:-1, -1], xticklabels=[], yticklabels=[])
    ax_bottom = fig.add_subplot(grid[-1, 0:-1], xticklabels=[], yticklabels=[])
    ax_main.scatter('lat', 'long', alpha=.9, data=df, cmap="Set1", edgecolors='black', linewidths=.5)
    sns.boxplot(y=df.long, ax=ax_right)
    sns.boxplot(x=df.lat, ax=ax_bottom)
    ax_bottom.set(xlabel='')
    ax_right.set(ylabel='')
#     plt.savefig(f'week_{week_number}.png')
    plt.show()

# %% [markdown]
# # Clean Data

# %%
import math
def filter(df_week,week_number):
    min_lat=df_week['lat'].min()
    while(min_lat<df_week['lat'].max()):
        interv=min_lat+1
        df_tmp=df_week[(df_week["lat"]<interv) & (df_week["lat"]>=min_lat) ]
        df_tmp_bar=df_week[df_week["lat"]>=interv]
        max_tmp=df_tmp['lat'].max()
        min_tmp_bar=df_tmp_bar['lat'].min()
        nb=df_tmp["id"].nunique()
        if((min_tmp_bar-max_tmp>0.1) ):
            print(f"from {min_lat} to {min_tmp_bar} mn3azl and we have {nb} id")
        if((min_tmp_bar-max_tmp>0.1) & (nb<3)):
#             if((min_tmp_bar+1>df_week['lat'].max()) & (df_tmp[df_tmp[]])):
#                 print(f"remove from {min_lat} to end we have {nb} id")
#                 df.loc[(df["week"]==week_number) &  (df['lat']>=min_lat),'id']='DEL'
#             else: 
            print(f"remove from {min_lat} to {min_tmp_bar} we have {nb} id")
            df.loc[(df["week"]==week_number) & (df['lat']<min_tmp_bar) & (df['lat']>=min_lat),'id']='DEL'
        elif(math.isnan(min_tmp_bar)):
            print(f"min is {min_tmp_bar}")
            if(df_week[df_week["lat"]>=min_lat]["id"].nunique()<3):
                print(f"remove from {min_lat} to end")
                df.loc[(df["week"]==week_number) &  (df['lat']>=min_lat),'id']='DEL'
        min_lat=min_tmp_bar

# %%
import math
def filterlong(df_week,week_number):
    min_lat=df_week['long'].min()
    while(min_lat<df_week['long'].max()):
        interv=min_lat+1
        df_tmp=df_week[(df_week["long"]<interv) & (df_week["long"]>=min_lat) ]
        df_tmp_bar=df_week[df_week["long"]>=interv]
        max_tmp=df_tmp['long'].max()
        min_tmp_bar=df_tmp_bar['long'].min()
        nb=df_tmp["id"].nunique()
        if((min_tmp_bar-max_tmp>0.1) ):
            print(f"from {min_lat} to {min_tmp_bar} mn3azl and we have {nb} id")
        if((min_tmp_bar-max_tmp>0.1) & (nb<3)):
#             if((min_tmp_bar+1>df_week['lat'].max()) & (df_tmp[df_tmp[]])):
#                 print(f"remove from {min_lat} to end we have {nb} id")
#                 df.loc[(df["week"]==week_number) &  (df['lat']>=min_lat),'id']='DEL'
#             else: 
            print(f"remove from {min_lat} to {min_tmp_bar} we have {nb} id")
            df.loc[(df["week"]==week_number) & (df['long']<min_tmp_bar) & (df['long']>=min_lat),'id']='DEL'
        elif(math.isnan(min_tmp_bar)):
            print(f"min is {min_tmp_bar}")
            if(df_week[df_week["long"]>=min_lat]["id"].nunique()<3):
                print(f"remove from {min_lat} to end")
                df.loc[(df["week"]==week_number) &  (df['long']>=min_lat),'id']='DEL'
        min_lat=min_tmp_bar

# %%
# for i in range(10, 21):
#     print("week "+str(i))
#     filter(df[df["week"]==i],i)
#     df_week_clean=df[(df["week"]==i) & (df['id']!='DEL')] 
#     plot(df_week_clean,i)
# Out:
# week 10
# from -46.8639016666667 to -1.67068884 mn3azl and we have 1 id
# remove from -46.8639016666667 to -1.67068884 we have 1 id
# from -1.67068884 to -0.646586666666667 mn3azl and we have 1 id
# remove from -1.67068884 to -0.646586666666667 we have 1 id
# from -0.646586666666667 to 0.63111 mn3azl and we have 10 id
# from 6.63189 to 11.3429983333333 mn3azl and we have 4 id
# from 11.3429983333333 to 14.404995 mn3azl and we have 1 id
# remove from 11.3429983333333 to 14.404995 we have 1 id
# min is nan
# remove from 14.404995 to end
# week 11
# from -5.74938833333333 to -1.60227 mn3azl and we have 1 id
# remove from -5.74938833333333 to -1.60227 we have 1 id
# from 10.444625 to 11.5742483333333 mn3azl and we have 1 id
# remove from 10.444625 to 11.5742483333333 we have 1 id
# min is nan
# remove from 14.5745666666667 to end
# week 12
# from 5.39038833333333 to 6.63524833333333 mn3azl and we have 8 id
# from 6.63524833333333 to 121.426093333333 mn3azl and we have 2 id
# remove from 6.63524833333333 to 121.426093333333 we have 2 id
# min is nan
# remove from 121.426093333333 to end
# week 13
# from -0.887836666666667 to 1.44975833333333 mn3azl and we have 2 id
# remove from -0.887836666666667 to 1.44975833333333 we have 2 id
# from 6.51454 to 121.375276666667 mn3azl and we have 3 id
# min is nan
# remove from 121.375276666667 to end
# week 14
# from -37.046425 to -29.9281066666667 mn3azl and we have 1 id
# remove from -37.046425 to -29.9281066666667 we have 1 id
# from -29.9281066666667 to -1.68093666666667 mn3azl and we have 1 id
# remove from -29.9281066666667 to -1.68093666666667 we have 1 id
# from -0.680825 to 1.32599 mn3azl and we have 2 id
# remove from -0.680825 to 1.32599 we have 2 id
# from 2.34705166666667 to 3.76067833333333 mn3azl and we have 2 id
# remove from 2.34705166666667 to 3.76067833333333 we have 2 id
# from 5.76071666666667 to 7.00824333333333 mn3azl and we have 7 id
# min is nan
# remove from 7.00824333333333 to end
# week 15
# from -97.770815 to -6.429905 mn3azl and we have 1 id
# remove from -97.770815 to -6.429905 we have 1 id
# from -6.429905 to -1.672965 mn3azl and we have 1 id
# remove from -6.429905 to -1.672965 we have 1 id
# from -1.672965 to 2.28033 mn3azl and we have 3 id
# min is nan
# remove from 6.28084333333333 to end
# week 16
# from -97.7549383333333 to -73.7893566666667 mn3azl and we have 1 id
# remove from -97.7549383333333 to -73.7893566666667 we have 1 id
# from -73.7893566666667 to -6.27831166666667 mn3azl and we have 1 id
# remove from -73.7893566666667 to -6.27831166666667 we have 1 id
# from -6.27831166666667 to -1.24946 mn3azl and we have 1 id
# remove from -6.27831166666667 to -1.24946 we have 1 id
# from -1.24946 to 0.0851133333333333 mn3azl and we have 1 id
# remove from -1.24946 to 0.0851133333333333 we have 1 id
# from 0.0851133333333333 to 1.87651666666667 mn3azl and we have 1 id
# remove from 0.0851133333333333 to 1.87651666666667 we have 1 id
# from 4.87703 to 6.54734333333333 mn3azl and we have 24 id
# min is nan
# remove from 6.54734333333333 to end
# week 17
# from -1.612045 to -0.571743333333333 mn3azl and we have 1 id
# remove from -1.612045 to -0.571743333333333 we have 1 id
# from -0.571743333333333 to 1.48918833333333 mn3azl and we have 2 id
# remove from -0.571743333333333 to 1.48918833333333 we have 2 id
# from 5.48981833333333 to 6.54787666666667 mn3azl and we have 2 id
# remove from 5.48981833333333 to 6.54787666666667 we have 2 id
# from 6.54787666666667 to 16.5643033333333 mn3azl and we have 1 id
# remove from 6.54787666666667 to 16.5643033333333 we have 1 id
# min is nan
# remove from 16.5643033333333 to end
# week 18
# from -2.32717333333333 to -1.32128333333333 mn3azl and we have 1 id
# remove from -2.32717333333333 to -1.32128333333333 we have 1 id
# from -0.320861666666667 to 0.843138333333333 mn3azl and we have 1 id
# remove from -0.320861666666667 to 0.843138333333333 we have 1 id
# from 6.84423666666667 to 16.3614233333333 mn3azl and we have 1 id
# remove from 6.84423666666667 to 16.3614233333333 we have 1 id
# from 16.3614233333333 to 17.4887283333333 mn3azl and we have 1 id
# remove from 16.3614233333333 to 17.4887283333333 we have 1 id
# min is nan
# remove from 17.4887283333333 to end
# week 19
# from -0.579855 to 2.26578833333333 mn3azl and we have 1 id
# remove from -0.579855 to 2.26578833333333 we have 1 id
# from 2.26578833333333 to 4.02307833333333 mn3azl and we have 3 id
# from 7.023345 to 8.5587 mn3azl and we have 1 id
# remove from 7.023345 to 8.5587 we have 1 id
# min is nan
# remove from 9.55871166666667 to end
# week 20
# from -17.4906166666667 to -5.45395666666667 mn3azl and we have 1 id
# remove from -17.4906166666667 to -5.45395666666667 we have 1 id
# from -5.45395666666667 to 2.27093666666667 mn3azl and we have 1 id
# remove from -5.45395666666667 to 2.27093666666667 we have 1 id
# from 2.27093666666667 to 4.58789166666667 mn3azl and we have 2 id
# remove from 2.27093666666667 to 4.58789166666667 we have 2 id
# min is nan

# %%
for i in range(10, 21):
    print("week "+str(i))
#     filterlong(df[df["week"]==i],i)
    df_week_clean=df[(df["week"]==i) & (df['id']!='DEL')] 
    plot(df_week_clean,i)
# Out:
# week 10
# week 11
# week 12
# week 13
# week 14
# week 15
# week 16
# week 17
# week 18
# week 19
# week 20

# %%
df_c=df[df["id"]!='DEL']
df_c.size/df.size
# Out:
# 0.9584517170123081

# %%
# df[df["week"]==12].groupby('id', as_index=False).size().sort_values('size')
df.shape

# %%
df.to_csv(f'clean_data2.csv', header=False, index=False,sep='\t')
