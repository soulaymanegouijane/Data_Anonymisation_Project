# %%
import pandas as pd
df = pd.read_csv("ano_week_20_19_18_16_11.csv",delimiter='\t',names=['id','datetime','lat','long',"week","ordre"],low_memory=False)
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.shape
# Out:
# (34551849, 6)

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
def plot(df,week_number):
    large = 22; med = 16; small = 12
    params = {'axes.titlesize': large,
              'legend.fontsize': med,
              'figure.figsize': (16, 10),
              'axes.labelsize': med,
              'axes.titlesize': med,
              'xtick.labelsize': med,
              'ytick.labelsize': med,
              'figure.titlesize': large}
    plt.rcParams.update(params)
    plt.style.use('seaborn-whitegrid')
    sns.set_style("white")
    # %matplotlib inline
    # Create Fig and gridspec
    fig = plt.figure(figsize=(16, 10), dpi= 80)
    grid = plt.GridSpec(4, 4, hspace=0.5, wspace=0.2)

    # Define the axes
    ax_main = fig.add_subplot(grid[:-1, :-1])
    ax_right = fig.add_subplot(grid[:-1, -1], xticklabels=[], yticklabels=[])
    ax_bottom = fig.add_subplot(grid[-1, 0:-1], xticklabels=[], yticklabels=[])
    ax_main.scatter('lat', 'long', alpha=.9, data=df, cmap="Set1", edgecolors='black', linewidths=.5)
    sns.boxplot(y=df.long, ax=ax_right)
    sns.boxplot(x=df.lat, ax=ax_bottom)
    ax_bottom.set(xlabel='')
    ax_right.set(ylabel='')
#     plt.savefig(f'week_{week_number}.png')
    plt.show()

# %%
# def see_long(mil,mal,wn):
#     df_tmp=df[(df['week']==wn) &(df['lat']<=mal) & (df['lat']>=mil) & (df['id']!='DEL')]
#     milo=df_tmp['long'].min()
#     malo=df_tmp['long'].max()
#     x=0.001
#     long_c=milo+x
#     ln=len(np.unique(df_tmp['id']))
#     if(ln<3 ):
#         df.loc[(df['week']==wn) &(df['lat']<=mal) & (df['lat']>=mil),'id']='DEL'
#     else:
#         mean_long=df_tmp['long'].mean()
#         df.loc[(df['week']==wn) & ((df['long']>=mean_long+0.001) | (df['long']<=mean_long-0.001)), 'id'] = 'DEL'
#         df.loc[(df['lat']<=mal) 
#                & (df['lat']>=mil) 
#                & (df['long']<=malo) 
#                & (df['long']>=milo)
#                ,['lat','long']] = df_tmp['lat'].mean(), mean_long

# %%
# def rand_long(mil,mal,wn):
#     df_tmp=df[(df['week']==wn) &(df['lat']<=mal) & (df['lat']>=mil) & (df['id']!='DEL')]
#     for i in range(df_tmp["ordre"].min(),df_tmp["ordre"].max()+1):
#         x=df[df["ordre"]==25]["long"].values[0]
#         y=x
#         if( i%2==0):
#             y += random.uniform(0, 0.099)
#         else:
#             y -= random.uniform(0, 0.099)
#         df.loc[(df['ordre']==i) 
#                ,['long']] = y
#         print(x,"-->",y)

# %%
def rand_long(mil,mal,wn):
    df_tmp=df[(df['week']==wn) &(df['lat']<=mal) & (df['lat']>=mil) & (df['id']!='DEL')]
    min_df=df_tmp["long"].min()
    max_df=df_tmp["long"].max()
    x=0.1
    long_c=min_df+x
    while(min_df<max_df):
        df.loc[(df['week']==wn) &(df['lat']<=mal) & (df['lat']>=mil) & (df['id']!='DEL')
               & (df['long']<=long_c) & (df['long']>=min_df)
               ,['long']] = random.uniform(min_df, long_c)
        min_df=long_c
        long_c+=x

# %%
import numpy as np
import random as random

def clean_data(dfw, wn):
    min_lat=dfw['lat'].min()
    max_lat=dfw['lat'].max()
    print(f"latmax {max_lat}")
    x=0.01
    lat_c=min_lat+x
    while min_lat<max_lat:
        df_int=[]
        print(f"lat {lat_c}")
        while x<0.1:
            df_int=dfw[ (dfw['lat']<lat_c) & (dfw['lat']>=min_lat) ]
            ln=len(np.unique(df_int['id']))
            if(ln>=3):
                df.loc[(df['lat']<=lat_c) 
                       & (df['lat']>=min_lat) 
                       ,['lat']] = df_int['lat'].mean()
                rand_long(min_lat,lat_c,wn)
                break;
            else:
                x+=x
                lat_c=min_lat+ x
        if((len(np.unique(df_int['id']))<3) | (x>=0.1)):
            df.loc[(df['week']==wn) & (df['lat']<lat_c) & (df['lat']>=min_lat), 'id'] = 'DEL'
        x=0.01
        min_lat=lat_c
        lat_c=min_lat+x

# %%
# def clean_data_long(dfw, wn):
#     min_lat=dfw['long'].min()
#     max_lat=dfw['long'].max()
#     print(f"long max {max_lat}")
#     x=0.001
#     lat_c=min_lat+x
#     while lat_c<max_lat:
#         df_int=[]
#         print(f"long {lat_c}")
#         while x<0.1:
#             df_int=dfw[ (dfw['long']<lat_c) & (dfw['long']>=min_lat) ]
#             ln=len(np.unique(df_int['id']))
#             if(ln>=3):
#                 z=x
#                 min_int_lat=min_lat
#                 max_int_lat=lat_c
#                 int_lat_c=min_int_lat+z
#                 while int_lat_c<=max_int_lat:
#                     see_long(min_int_lat,int_lat_c,wn)
#                     min_int_lat=int_lat_c
#                     int_lat_c+=z
#                 break;
#             else:
#                 x+=x
#                 lat_c+=x
#         if((len(np.unique(df_int['id']))<3) | (x>=0.1)):
#             df.loc[(df['week']==wn) & (df['long']<lat_c) & (df['long']>=min_lat), 'id'] = 'DEL'
#         x=0.001
#         min_lat=lat_c
#         lat_c=min_lat+x

# %%
for i in range(10, 11):
    print("week "+str(i))
    df_w = df[(df["week"]==i)&(df["id"]!="DEL")]
    clean_data(df_w,i)
    df_p = df[(df["week"]==i)&(df["id"]!="DEL")]
    plot(df_p,i)
# Out:
# week 10
# latmax 6.94
# lat -0.636586666666667
# lat -0.626586666666667
# lat -0.616586666666667
# lat -0.5765866666666669
# lat -0.5665866666666669
# lat -0.5565866666666669
# lat -0.5465866666666669
# lat -0.5365866666666669
# lat -0.37658666666666685
# lat -0.21658666666666684
# lat -0.05658666666666685
# lat 0.10341333333333315
# lat 0.26341333333333317
# lat 0.4234133333333332
# lat 0.5834133333333332
# lat 0.7434133333333333
# lat 0.9034133333333333
# lat 1.0634133333333333
# lat 1.2234133333333332
# lat 1.3834133333333332
# lat 1.543413333333333
# lat 1.703413333333333
# lat 1.863413333333333
# lat 2.0234133333333326
# lat 5.483413333333283
# lat 5.493413333333283
# lat 5.513413333333283
# lat 5.523413333333282
# lat 5.533413333333282
# lat 5.543413333333282
# lat 5.553413333333282
# lat 5.563413333333282
# lat 5.573413333333281
# lat 5.583413333333281
# lat 5.593413333333281
# lat 5.603413333333281
# lat 5.6134133333332805
# lat 5.62341333333328
# lat 5.63341333333328
# lat 5.64341333333328
# lat 5.65341333333328
# lat 5.6634133333332795
# lat 5.673413333333279
# lat 5.683413333333279
# lat 5.693413333333279
# lat 5.703413333333279
# lat 5.713413333333278
# lat 5.733413333333278
# lat 5.743413333333278
# lat 5.763413333333277
# lat 5.773413333333277
# lat 5.793413333333277
# lat 5.8034133333332765
# lat 5.813413333333276
# lat 5.853413333333276
# lat 5.873413333333276
# lat 5.883413333333276
# lat 5.903413333333275
# lat 5.913413333333275
# lat 5.923413333333275
# lat 5.933413333333275
# lat 5.943413333333274
# lat 5.953413333333274
# lat 5.963413333333274
# lat 5.973413333333274
# lat 5.9834133333332735
# lat 5.993413333333273
# lat 6.013413333333273
# lat 6.023413333333273
# lat 6.0334133333332725
# lat 6.043413333333272
# lat 6.053413333333272
# lat 6.073413333333272
# lat 6.083413333333271
# lat 6.093413333333271
# lat 6.103413333333271
# lat 6.113413333333271
# lat 6.13341333333327
# lat 6.14341333333327
# lat 6.18341333333327
# lat 6.19341333333327
# lat 6.20341333333327
# lat 6.2134133333332695
# lat 6.223413333333269
# lat 6.233413333333269
# lat 6.243413333333269
# lat 6.253413333333269
# lat 6.263413333333268
# lat 6.273413333333268
# lat 6.293413333333268
# lat 6.313413333333267
# lat 6.323413333333267
# lat 6.333413333333267
# lat 6.343413333333267
# lat 6.3534133333332665
# lat 6.363413333333266
# lat 6.373413333333266
# lat 6.383413333333266
# lat 6.393413333333266
# lat 6.4034133333332655
# lat 6.413413333333265
# lat 6.423413333333265
# lat 6.433413333333265
# lat 6.513413333333265
# lat 6.523413333333265
# lat 6.5334133333332645
# lat 6.543413333333264
# lat 6.553413333333264
# lat 6.563413333333264
# lat 6.573413333333264
# lat 6.583413333333263
# lat 6.593413333333263
# lat 6.603413333333263
# lat 6.613413333333263
# lat 6.6234133333332625
# lat 6.633413333333262
# lat 6.643413333333262
# lat 6.653413333333262
# lat 6.693413333333262
# lat 6.703413333333262
# lat 6.7134133333332615
# lat 6.723413333333261
# lat 6.883413333333261

# %%
w=10
klwa = df[(df["week"]==w)&(df["id"]!="DEL")]
plot(klwa,10)

# %%
# df_c.size/df[df["week"]==10].size
# for i in range(10, 21):
#     print("week "+str(i))
# #     filterlong(df[df["week"]==i],i)
#     df_week_clean=df[(df["week"]==i) & (df['id']!='DEL')] 
#     plot(df_week_clean,i)

# %%
df.to_csv(f'ano_week_20_19_18_16_11_10.csv', header=False, index=False,sep='\t')

# %%
df[(df["week"]==18) & (df['id']!='DEL')].size/df[df["week"]==18].size
# Out:
# 0.8191658704277098
